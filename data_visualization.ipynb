# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# # Fetch Data

# %%
from warnings import filterwarnings
filterwarnings("ignore")

import pandas as pd
A = pd.read_csv("C:/Users/Shruti/Downloads/Cars93.csv")

# %%
A.head(2)
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                None  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
#
#    Turn.circle  Rear.seat.room Luggage.room  Weight   Origin           Make
# 0           37            26.5         11.0    2705  non-USA  Acura Integra
# 1           38            30.0         15.0    3560  non-USA   Acura Legend
#
# [2 rows x 28 columns]

# %% [markdown]
# # Seperating categorical and continuous columns

# %%
cat = []
con = []
for i in A.columns:
    if(A[i].dtypes == "object"):
        cat.append(i)
    else:
        con.append(i)

# %% [markdown]
# # Univariate plots(plot of 1 column)
#     1. Continuous --> distribution plot, histogram(Spread of data)
#     2. Categorical --> pie, HorBar char, VerBar chart

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %% [raw]
# Continuous:

# %%
sb.distplot(A.Price)

# %%
A.Price.hist()

# %% [raw]
# categorical:

# %%
#bar:
A.Type.value_counts().plot(kind="bar")
plt.xlabel("Car Type")
plt.ylabel("No of cars")
plt.yticks(range(0,26,3))
# Out:
# ([<matplotlib.axis.YTick at 0x296eb212fa0>,
# ...
#  <a list of 9 Text major ticklabel objects>)

# %%
#horizontal_bar:
A.Type.value_counts().plot(kind="barh")

# %%
#pile:
A.Type.value_counts().plot(kind="pie")

# %% [markdown]
# # Subplot

# %%
plt.figure(figsize=(30,60))

x = 1

for i in A.columns:
    if(A[i].dtypes == "object"):
        plt.subplot(14,2,x)
        A[i].value_counts().plot(kind="barh")
        x = x + 1
    else:
        plt.subplot(14,2,x)
        sb.distplot(A[i])
        x = x+1

# %% [markdown]
# # Bivariate analysis
#    1. Both the columns are continuous(Correlation, Scatterplot)
#    2. One is cat, Another is con(ANOVA, Boxplot)
#    3. Both the variables are categorical(Cross Tabulation | Countplot with Hue)

# %% [raw]
# 1. Scatterplot (con,con):

# %%
sb.scatterplot(A.Price,A.Horsepower)

# %%
A.corr()
# Out:
#                           id  Min.Price     Price  Max.Price  MPG.city  \
# id                  1.000000  -0.144463 -0.137277  -0.126567  0.161808
# Min.Price          -0.144463   1.000000  0.970601   0.906756 -0.622875
# Price              -0.137277   0.970601  1.000000   0.981580 -0.594562
# Max.Price          -0.126567   0.906756  0.981580   1.000000 -0.547811
# MPG.city            0.161808  -0.622875 -0.594562  -0.547811  1.000000
# MPG.highway         0.137317  -0.579966 -0.560680  -0.522561  0.943936
# EngineSize         -0.338286   0.645488  0.597425   0.535012 -0.710003
# Horsepower         -0.233012   0.802444  0.788218   0.744445 -0.672636
# RPM                 0.167772  -0.042598 -0.004955   0.025015  0.363045
# Rev.per.mile        0.226389  -0.470395 -0.426395  -0.374024  0.695857
# Fuel.tank.capacity -0.179034   0.635369  0.619480   0.581294 -0.813144
# Passengers         -0.142252   0.061236  0.057860   0.053216 -0.416856
# ...

# %% [raw]
# 2. Boxplot(cat,con):

# %%
sb.boxplot(A.Type,A.Price)

# %%
sb.boxplot(A.Type,A.Price,order=["Small","Compact","Sporty","Midsize","Large","Van"])

# %% [raw]
# 3. count plot with hue (cat,cat)

# %%
sb.countplot(A["Type"],hue = A["Origin"])
